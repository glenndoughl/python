# %%
from openpyxl import Workbook, load_workbook
import csv
import time
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
day_offset = 1#input("Day Offset: ")
yyyymmdd_min1d = (datetime.now()+relativedelta(days=day_offset)).strftime("%Y%m%d") #get date in yyyymmdd-1day (ie: 20221018)
yyyy = datetime.now().strftime("%Y") #get year in YYYY format (ie: 2022)

if int(datetime.now().strftime("%d")) > 25:
    month_offset = 1
else:
    month_offset = 0

mm_Mmmm = (datetime.now()+relativedelta(months=month_offset)).strftime("%m %B")  #get current month in MM_MMMM format (ie: 10 October)
mmmm = (datetime.now()+relativedelta(months=month_offset)).strftime("%m %B")  #get month in MMMM (ie: October)
yyyy = datetime.now().strftime("%Y") #get year in YYYY format (ie: 2022)

# %%
CIP = 1#input("CIP new DGO: ")
BPGC = 2#input("BPGC new DGO: ")
OSPGC = 3#input("OSPGC new DGO: ")
values = [CIP, BPGC, OSPGC]

files_conf = {
        "file1":{
        "path":rf"C:\Users\glenn\Downloads\Sample Macro.xlsm",
        "sheetname":"Sheet1",
        "cells":["S3","T3","U3"],
        "newvalue": values
        },
    "file2":{
        "path":rf"C:\Users\glenn\Downloads\Sample Macro - Copy.xlsm",
        "sheetname":"Sheet2",
        "cells":["B2","B3","B4"],
        "newvalue": values
        },
    "file3":{
        "path":rf"C:\Users\glenn\Downloads\Sample Macro - Copy (2).xlsm",
        "sheetname":"Sheet3",
        "cells":["C2","C3","C4"],
        "newvalue": values
        },
    "file4":{
        "path":rf"C:\Users\glenn\Downloads\Sample Macro - Copy (3).xlsm",
        "sheetname":"Sheet4",
        "cells":["C1","C2","C3"],
        "newvalue": values
        }
}
    # "file1":{
    #     "path":rf"C:\Users\aspan.clr\AC Energy, Inc\Internal Document Library - 04 Trading\Trading Operations\10. ST",
    #     "sheetname":"Price vs. RTD",
    #     "cells":["S3","T3","U3"],
    #     "newvalue": "1"
    #     },
    # "file2":{
    #     "path":rf"C:\Users\aspan.clr\AC Energy, Inc\Internal Document Library - 04 Trading\Trading Operations\10. ST\GAMBIT\{yyyy}\{mm_Mmmm}",
    #     "sheetname":"sheet2",
    #     "cells":["B2","B3","B4"],
    #     "newvalue": "2"
    #     },
    # "file3":{
    #     "path":rf"C:\Users\aspan.clr\AC Energy, Inc\Internal Document Library - 04 Trading\Trading Operations\03.PM\BCQ\EWDO\MQ CONVERTER\{yyyymmdd_min1d}",
    #     "sheetname":"sheet3",
    #     "cells":["C2","C3","C4"],
    #     "newvalue": "3"
    #     },
    # "file4":{
    #     "path":rf"C:\Users\aspan.clr\AC Energy, Inc\Internal Document Library - 04 Trading\Trading Operations\01.AM\ASPA\AM2 Cheat Sheet",
    #     "sheetname":"sheet4",
    #     "cells":["C1","C2","C3"],
    #     "newvalue": "4"
    #     },

# %%
for conf in files_conf:
    
    FilePath = files_conf[conf]["path"]
    SheetName =  files_conf[conf]["sheetname"]
    CellNumbers =  files_conf[conf]["cells"]
    New_Value = files_conf[conf]["newvalue"]

    print(f"""
    EDITING:
    File: {FilePath}
    Sheet: {SheetName}
    Plants: [CIP,BPGC,OSPGC]
    Cells: {CellNumbers}
    New Values: {New_Value}""")


    wb = load_workbook(rf"{FilePath}", keep_vba=True)
    ws = wb[SheetName]
    for i in range(3):
        ws[CellNumbers[i]] = New_Value[i]
        print(f"{CellNumbers[i]} = {New_Value[i]}")
    wb.save(FilePath)

    print(f"""DONE - Saved to: {FilePath}
**************************************************************************""")
# Out:
#     EDITING:
#     File: C:\Users\glenn\Downloads\Sample Macro.xlsm
#     Sheet: Sheet1
#     Plants: [CIP,BPGC,OSPGC]
#     Cells: ['S3', 'T3', 'U3']
#     New Values: [1, 2, 3]
# S3 = 1
# T3 = 2
# U3 = 3
# DONE - Saved to: C:\Users\glenn\Downloads\Sample Macro.xlsm
# **************************************************************************
#
#     EDITING:
#     File: C:\Users\glenn\Downloads\Sample Macro - Copy.xlsm
#     Sheet: Sheet2
#     Plants: [CIP,BPGC,OSPGC]
#     Cells: ['B2', 'B3', 'B4']
#     New Values: [1, 2, 3]
# B2 = 1
# B3 = 2
# B4 = 3
# DONE - Saved to: C:\Users\glenn\Downloads\Sample Macro - Copy.xlsm
# **************************************************************************
#
#     EDITING:
#     File: C:\Users\glenn\Downloads\Sample Macro - Copy (2).xlsm
#     Sheet: Sheet3
#     Plants: [CIP,BPGC,OSPGC]
#     Cells: ['C2', 'C3', 'C4']
#     New Values: [1, 2, 3]
# C2 = 1
# C3 = 2
# C4 = 3
# DONE - Saved to: C:\Users\glenn\Downloads\Sample Macro - Copy (2).xlsm
# **************************************************************************
#
#     EDITING:
#     File: C:\Users\glenn\Downloads\Sample Macro - Copy (3).xlsm
#     Sheet: Sheet4
#     Plants: [CIP,BPGC,OSPGC]
#     Cells: ['C1', 'C2', 'C3']
#     New Values: [1, 2, 3]
# C1 = 1
# C2 = 2
# C3 = 3
# DONE - Saved to: C:\Users\glenn\Downloads\Sample Macro - Copy (3).xlsm
# **************************************************************************
